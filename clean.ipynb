# %%
import pandas as pd
import numpy as np
import regex as re
from fancyimpute import KNN
# we increase the maximum display number in order to be able to see some columns that we weren't able to see before,
# as though the two columns between 'Sex' and 'Fatal(Y/N)', which are 'Age' and 'Injury', weren't displayed at first.
pd.set_option("display.max_columns", 120)

# %%
# !ls ../Pandas-project
# Out:
# README.md         attacks.csv       clean.ipynb
# analysis.ipynb    attacks_clean.csv

# %%
file = '../Pandas-project/attacks.csv'
df = pd.read_csv(file)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf3 in position 7: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-617-99dec51564e8> in <module>
#       1 file = '../Pandas-project/attacks.csv'
# ----> 2 df = pd.read_csv(file)
#
# /usr/local/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# /usr/local/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     458
#     459     try:
# --> 460         data = parser.read(nrows)
#     461     finally:
#     462         parser.close()
#
# /usr/local/lib/python3.8/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1196     def read(self, nrows=None):
#    1197         nrows = _validate_integer("nrows", nrows)
# -> 1198         ret = self._engine.read(nrows)
#    1199
#    1200         # May alter columns / col_dict
#
# /usr/local/lib/python3.8/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2155     def read(self, nrows=None):
#    2156         try:
# -> 2157             data = self._reader.read(nrows)
#    2158         except StopIteration:
#    2159             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf3 in position 7: invalid continuation byte

# %%
# We had to introduce a decoder in order to visualize the dataset, as it was printing an error of 'utf-8' encoding.
# The info from were we obtained the info to solve this problem can be found in this Kaggle post:
# "https://www.kaggle.com/paultimothymooney/how-to-resolve-a-unicodedecodeerror-for-a-csv-file"

import chardet

with open(file, 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
result
# Out:
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}

# %%
# We introduce the 'encoding' parameter and there we go, the table of this set is printed!

df = pd.read_csv(file, encoding='Windows-1252')
df.head(5)
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               Injury Fatal (Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...           N
# 1                         Minor injury to left thigh           N
# 2       Injury to left lower leg from surfboard skeg           N
# 3                          Minor injury to lower leg           N
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT           N
#
#             Time         Species           Investigator or Source  \
# 0          18h00      White shark                R. Collier, GSAF
# 1  14h00  -15h00              NaN  K.McMurray, TrackingSharks.com
# 2          07h45              NaN  K.McMurray, TrackingSharks.com
# 3            NaN        2 m shark                  B. Myatt, GSAF
# 4            NaN  Tiger shark, 3m                       A .Kipper
#
#                         pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
#
#   Case Number.2  original order Unnamed: 22 Unnamed: 23
# 0    2018.06.25          6303.0         NaN         NaN
# 1    2018.06.18          6302.0         NaN         NaN
# 2    2018.06.09          6301.0         NaN         NaN
# 3    2018.06.08          6300.0         NaN         NaN
# 4    2018.06.04          6299.0         NaN         NaN

# %%
# We clean the latest to columns because we ran several .samples() and none of them showed that they actually had
# any useful info.
to_drop = ['Unnamed: 22', 'Unnamed: 23']

df.drop(to_drop, inplace=True, axis=1)

# %%
# I was thinking about to delete column 'Case number.2' as I thought they were exactly the same but with different
# names. But after running several samples, they showed a difference in one of them.

# %%
# We observe now the two columns 'href formula' and 'href', as they might store the same links and information
# but twice, so that wouldn't be neccessary.
df.head(5)
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               Injury Fatal (Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...           N
# 1                         Minor injury to left thigh           N
# 2       Injury to left lower leg from surfboard skeg           N
# 3                          Minor injury to lower leg           N
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT           N
#
#             Time         Species           Investigator or Source  \
# 0          18h00      White shark                R. Collier, GSAF
# 1  14h00  -15h00              NaN  K.McMurray, TrackingSharks.com
# 2          07h45              NaN  K.McMurray, TrackingSharks.com
# 3            NaN        2 m shark                  B. Myatt, GSAF
# 4            NaN  Tiger shark, 3m                       A .Kipper
#
#                         pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
#
#   Case Number.2  original order
# 0    2018.06.25          6303.0
# 1    2018.06.18          6302.0
# 2    2018.06.09          6301.0
# 3    2018.06.08          6300.0
# 4    2018.06.04          6299.0

# %%
df['href formula']
# Out:
# 0        http://sharkattackfile.net/spreadsheets/pdf_di...
# 1        http://sharkattackfile.net/spreadsheets/pdf_di...
# 2        http://sharkattackfile.net/spreadsheets/pdf_di...
# 3        http://sharkattackfile.net/spreadsheets/pdf_di...
# 4        http://sharkattackfile.net/spreadsheets/pdf_di...
#                                ...
# 25718                                                  NaN
# 25719                                                  NaN
# 25720                                                  NaN
# 25721                                                  NaN
# 25722                                                  NaN
# Name: href formula, Length: 25723, dtype: object

# %%
df['href']
# Out:
# 0        http://sharkattackfile.net/spreadsheets/pdf_di...
# 1        http://sharkattackfile.net/spreadsheets/pdf_di...
# 2        http://sharkattackfile.net/spreadsheets/pdf_di...
# 3        http://sharkattackfile.net/spreadsheets/pdf_di...
# 4        http://sharkattackfile.net/spreadsheets/pdf_di...
#                                ...
# 25718                                                  NaN
# 25719                                                  NaN
# 25720                                                  NaN
# 25721                                                  NaN
# 25722                                                  NaN
# Name: href, Length: 25723, dtype: object

# %%
# It looks as they store the same info and their lenght is exactly the same, so we've decided to delete one of them.
df.drop(['href formula'], inplace=True, axis=1)

# %%
df.sample(5)
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 7655            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 11089         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 20884         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8747          NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 14911         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        Age Injury Fatal (Y/N) Time Species  Investigator or Source  pdf href  \
# 7655   NaN    NaN         NaN  NaN      NaN                    NaN  NaN  NaN
# 11089  NaN    NaN         NaN  NaN      NaN                    NaN  NaN  NaN
# 20884  NaN    NaN         NaN  NaN      NaN                    NaN  NaN  NaN
# 8747   NaN    NaN         NaN  NaN      NaN                    NaN  NaN  NaN
# 14911  NaN    NaN         NaN  NaN      NaN                    NaN  NaN  NaN
#
#       Case Number.1 Case Number.2  original order
# 7655            NaN           NaN             NaN
# 11089           NaN           NaN             NaN
# 20884           NaN           NaN             NaN
# 8747            NaN           NaN             NaN
# 14911           NaN           NaN             NaN

# %%
# Another thing we've noticed is that the links are completely broken, none of them work and all of them display
# the message: '404 Not Found, The requested URL was not found on this server.' But when opening the .csv with 
# another program, they seem to work just fine.

# %%
# There are a lot of "NaN's" values in this dataset, so we will have to deal with them.
df.sample(5)
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 17149         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 19260         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 17644         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 12941         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 24371         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        Age Injury Fatal (Y/N) Time Species  Investigator or Source  pdf href  \
# 17149  NaN    NaN         NaN  NaN      NaN                    NaN  NaN  NaN
# 19260  NaN    NaN         NaN  NaN      NaN                    NaN  NaN  NaN
# 17644  NaN    NaN         NaN  NaN      NaN                    NaN  NaN  NaN
# 12941  NaN    NaN         NaN  NaN      NaN                    NaN  NaN  NaN
# 24371  NaN    NaN         NaN  NaN      NaN                    NaN  NaN  NaN
#
#       Case Number.1 Case Number.2  original order
# 17149           NaN           NaN             NaN
# 19260           NaN           NaN             NaN
# 17644           NaN           NaN             NaN
# 12941           NaN           NaN             NaN
# 24371           NaN           NaN             NaN

# %%
# We delete also the "Case Number" column to be able to reduce our dataframe to 6000 columns or so.
df.drop(['Case Number'], inplace=True, axis=1)

# %%
# We drop all rows with "NaN" values only.
df.dropna(how="all", inplace=True)

# %%
# After printing the top 5 positions of the list, we notice that the last column called 'original order' seems to be
# a float type, also filled with 'NaN' values throughout the complete list, so we need to clean that column.
df.dtypes
# Out:
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# dtype: object

# %%
df
# Out:
#              Date    Year        Type    Country             Area  \
# 0     25-Jun-2018  2018.0     Boating        USA       California
# 1     18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2     09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3     08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4     04-Jun-2018  2018.0    Provoked     MEXICO           Colima
# ...           ...     ...         ...        ...              ...
# 6304          NaN     NaN         NaN        NaN              NaN
# 6305          NaN     NaN         NaN        NaN              NaN
# 6306          NaN     NaN         NaN        NaN              NaN
# 6307          NaN     NaN         NaN        NaN              NaN
# 6308          NaN     NaN         NaN        NaN              NaN
#
#                             Location     Activity             Name Sex   Age  \
# 0        Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1     St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                       Habush, Oahu      Surfing      John Denges    M   48
# 3                 Arrawarra Headland      Surfing             male    M  NaN
# 4                           La Ticla  Free diving   Gustavo Ramos     M  NaN
# ...                              ...          ...              ...  ...  ...
# 6304                             NaN          NaN              NaN  NaN  NaN
# 6305                             NaN          NaN              NaN  NaN  NaN
# 6306                             NaN          NaN              NaN  NaN  NaN
# 6307                             NaN          NaN              NaN  NaN  NaN
# 6308                             NaN          NaN              NaN  NaN  NaN
#
#                                                  Injury Fatal (Y/N)  \
# 0     No injury to occupant, outrigger canoe and pad...           N
# 1                            Minor injury to left thigh           N
# 2          Injury to left lower leg from surfboard skeg           N
# 3                             Minor injury to lower leg           N
# 4     Lacerations to leg & hand shark PROVOKED INCIDENT           N
# ...                                                 ...         ...
# 6304                                                NaN         NaN
# 6305                                                NaN         NaN
# 6306                                                NaN         NaN
# 6307                                                NaN         NaN
# 6308                                                NaN         NaN
#
#                Time         Species           Investigator or Source  \
# 0             18h00      White shark                R. Collier, GSAF
# 1     14h00  -15h00              NaN  K.McMurray, TrackingSharks.com
# 2             07h45              NaN  K.McMurray, TrackingSharks.com
# 3               NaN        2 m shark                  B. Myatt, GSAF
# 4               NaN  Tiger shark, 3m                       A .Kipper
# ...             ...              ...                             ...
# 6304            NaN              NaN                             NaN
# 6305            NaN              NaN                             NaN
# 6306            NaN              NaN                             NaN
# 6307            NaN              NaN                             NaN
# 6308            NaN              NaN                             NaN
#
#                            pdf  \
# 0         2018.06.25-Wolfe.pdf
# 1       2018.06.18-McNeely.pdf
# 2        2018.06.09-Denges.pdf
# 3     2018.06.08-Arrawarra.pdf
# 4         2018.06.04-Ramos.pdf
# ...                        ...
# 6304                       NaN
# 6305                       NaN
# 6306                       NaN
# 6307                       NaN
# 6308                       NaN
#
#                                                    href Case Number.1  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                 ...           ...
# 6304                                                NaN           NaN
# 6305                                                NaN           NaN
# 6306                                                NaN           NaN
# 6307                                                NaN           NaN
# 6308                                                NaN           NaN
#
#      Case Number.2  original order
# 0       2018.06.25          6303.0
# 1       2018.06.18          6302.0
# 2       2018.06.09          6301.0
# 3       2018.06.08          6300.0
# 4       2018.06.04          6299.0
# ...            ...             ...
# 6304           NaN          6306.0
# 6305           NaN          6307.0
# 6306           NaN          6308.0
# 6307           NaN          6309.0
# 6308           NaN          6310.0
#
# [6309 rows x 20 columns]

# %%
df
# Out:
#              Date    Year        Type    Country             Area  \
# 0     25-Jun-2018  2018.0     Boating        USA       California
# 1     18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2     09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3     08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4     04-Jun-2018  2018.0    Provoked     MEXICO           Colima
# ...           ...     ...         ...        ...              ...
# 6304          NaN     NaN         NaN        NaN              NaN
# 6305          NaN     NaN         NaN        NaN              NaN
# 6306          NaN     NaN         NaN        NaN              NaN
# 6307          NaN     NaN         NaN        NaN              NaN
# 6308          NaN     NaN         NaN        NaN              NaN
#
#                             Location     Activity             Name Sex   Age  \
# 0        Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1     St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                       Habush, Oahu      Surfing      John Denges    M   48
# 3                 Arrawarra Headland      Surfing             male    M  NaN
# 4                           La Ticla  Free diving   Gustavo Ramos     M  NaN
# ...                              ...          ...              ...  ...  ...
# 6304                             NaN          NaN              NaN  NaN  NaN
# 6305                             NaN          NaN              NaN  NaN  NaN
# 6306                             NaN          NaN              NaN  NaN  NaN
# 6307                             NaN          NaN              NaN  NaN  NaN
# 6308                             NaN          NaN              NaN  NaN  NaN
#
#                                                  Injury Fatal (Y/N)  \
# 0     No injury to occupant, outrigger canoe and pad...           N
# 1                            Minor injury to left thigh           N
# 2          Injury to left lower leg from surfboard skeg           N
# 3                             Minor injury to lower leg           N
# 4     Lacerations to leg & hand shark PROVOKED INCIDENT           N
# ...                                                 ...         ...
# 6304                                                NaN         NaN
# 6305                                                NaN         NaN
# 6306                                                NaN         NaN
# 6307                                                NaN         NaN
# 6308                                                NaN         NaN
#
#                Time         Species           Investigator or Source  \
# 0             18h00      White shark                R. Collier, GSAF
# 1     14h00  -15h00              NaN  K.McMurray, TrackingSharks.com
# 2             07h45              NaN  K.McMurray, TrackingSharks.com
# 3               NaN        2 m shark                  B. Myatt, GSAF
# 4               NaN  Tiger shark, 3m                       A .Kipper
# ...             ...              ...                             ...
# 6304            NaN              NaN                             NaN
# 6305            NaN              NaN                             NaN
# 6306            NaN              NaN                             NaN
# 6307            NaN              NaN                             NaN
# 6308            NaN              NaN                             NaN
#
#                            pdf  \
# 0         2018.06.25-Wolfe.pdf
# 1       2018.06.18-McNeely.pdf
# 2        2018.06.09-Denges.pdf
# 3     2018.06.08-Arrawarra.pdf
# 4         2018.06.04-Ramos.pdf
# ...                        ...
# 6304                       NaN
# 6305                       NaN
# 6306                       NaN
# 6307                       NaN
# 6308                       NaN
#
#                                                    href Case Number.1  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                 ...           ...
# 6304                                                NaN           NaN
# 6305                                                NaN           NaN
# 6306                                                NaN           NaN
# 6307                                                NaN           NaN
# 6308                                                NaN           NaN
#
#      Case Number.2  original order
# 0       2018.06.25          6303.0
# 1       2018.06.18          6302.0
# 2       2018.06.09          6301.0
# 3       2018.06.08          6300.0
# 4       2018.06.04          6299.0
# ...            ...             ...
# 6304           NaN          6306.0
# 6305           NaN          6307.0
# 6306           NaN          6308.0
# 6307           NaN          6309.0
# 6308           NaN          6310.0
#
# [6309 rows x 20 columns]

# %%
df['original order']
# Out:
# 0       6303.0
# 1       6302.0
# 2       6301.0
# 3       6300.0
# 4       6299.0
#          ...
# 6304    6306.0
# 6305    6307.0
# 6306    6308.0
# 6307    6309.0
# 6308    6310.0
# Name: original order, Length: 6309, dtype: float64

# %%
# Now we want to test if two columns are exactly the same or not. Here's a little example:
# We create a random dataframe and put it to the test.
sd = pd.DataFrame({'a': [1,2,3], 'b': [1,2,4]})
sd
# Out:
#    a  b
# 0  1  1
# 1  2  2
# 2  3  4

# %%
comps = np.where(sd["a"] == sd["b"], True, False)
print(comps)
# As we can see, the test works perfectly fine. The first two columns are the same so the output is "True",
# While the third column is not the same so the output is "False".
# Out:
# [ True  True False]

# %%
# Now we do that with our actual dataset. The intention is to test if the columns "Case Number.1" and 
# the other column "Case Number.2" are the same of they contain different info.
comp = np.where(df["Case Number.1"] == df["Case Number.2"], True, False)
print(comp)
# Out:
# [ True  True  True ... False False False]

# %%
# We get some "False" outputs, so we need to look closer to see if the result is valid.
df["equal"] = comp
print(df)
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# 25718              NaN                             NaN          NaN
# 25719              NaN                             NaN          NaN
# 25720              NaN                             NaN          NaN
# 25721              NaN                             NaN          NaN
# 25722              NaN                             NaN          NaN
#
#                   Name Sex   Age  \
# 0          Julie Wolfe    F   57
# 1      Adyson McNeely     F   11
# 2          John Denges    M   48
# 3                 male    M  NaN
# 4       Gustavo Ramos     M  NaN
# ...                ...  ...  ...
# 25718              NaN  NaN  NaN
# 25719              NaN  NaN  NaN
# 25720              NaN  NaN  NaN
# 25721              NaN  NaN  NaN
# 25722              NaN  NaN  NaN
#
#                                                   Injury Fatal (Y/N)  \
# 0      No injury to occupant, outrigger canoe and pad...           N
# 1                             Minor injury to left thigh           N
# 2           Injury to left lower leg from surfboard skeg           N
# 3                              Minor injury to lower leg           N
# 4      Lacerations to leg & hand shark PROVOKED INCIDENT           N
# ...                                                  ...         ...
# 25718                                                NaN         NaN
# 25719                                                NaN         NaN
# 25720                                                NaN         NaN
# 25721                                                NaN         NaN
# 25722                                                NaN         NaN
#
#                 Time         Species           Investigator or Source  \
# 0              18h00      White shark                R. Collier, GSAF
# 1      14h00  -15h00              NaN  K.McMurray, TrackingSharks.com
# 2              07h45              NaN  K.McMurray, TrackingSharks.com
# 3                NaN        2 m shark                  B. Myatt, GSAF
# 4                NaN  Tiger shark, 3m                       A .Kipper
# ...              ...              ...                             ...
# 25718            NaN              NaN                             NaN
# 25719            NaN              NaN                             NaN
# 25720            NaN              NaN                             NaN
# 25721            NaN              NaN                             NaN
# 25722            NaN              NaN                             NaN
#
#                             pdf  \
# 0          2018.06.25-Wolfe.pdf
# 1        2018.06.18-McNeely.pdf
# 2         2018.06.09-Denges.pdf
# 3      2018.06.08-Arrawarra.pdf
# 4          2018.06.04-Ramos.pdf
# ...                         ...
# 25718                       NaN
# 25719                       NaN
# 25720                       NaN
# 25721                       NaN
# 25722                       NaN
#
#                                                     href Case Number.1  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                  ...           ...
# 25718                                                NaN           NaN
# 25719                                                NaN           NaN
# 25720                                                NaN           NaN
# 25721                                                NaN           NaN
# 25722                                                NaN           NaN
#
#       Case Number.2  original order  equal
# 0        2018.06.25          6303.0   True
# 1        2018.06.18          6302.0   True
# 2        2018.06.09          6301.0   True
# 3        2018.06.08          6300.0   True
# 4        2018.06.04          6299.0   True
# ...             ...             ...    ...
# 25718           NaN             0.0  False
# 25719           NaN             0.0  False
# 25720           NaN             0.0  False
# 25721           NaN             0.0  False
# 25722           NaN             0.0  False
#
# [25723 rows x 22 columns]

# %%
# As we can see, the "False" output seems to be in the comparison between "NaN" values/data types.
# So we check once again to make sure that this is so.
NaN_1 = np.nan
NaN_2 = np.nan

print(NaN_1 == NaN_2)
# Out:
# False

# %%
# So the final conclusion is that the columns "Case Number.1" and "Case Number.2" are probably the same
# We once again proceed to remove the second one because we won't need both of them for the analysis.

# %%
df.drop("Case Number.2", inplace=True, axis=1)

# %%
# We also need to drop the aforementioned column called "equal" as we only needed it for a check.
df.drop("equal", inplace=True, axis=1)

# %%
df.sample(10)
# Out:
#              Date    Year          Type         Country             Area  \
# 582   08-Feb-2014  2014.0    Unprovoked       AUSTRALIA  South Australia
# 5913  01-Jun-1870  1870.0    Unprovoked           INDIA      West Bengal
# 5255  08-Mar-1920  1920.0    Unprovoked       AUSTRALIA       Queensland
# 4578  20-Apr-1947  1947.0    Unprovoked    SOUTH AFRICA    KwaZulu-Natal
# 4707  12-Jul-1942  1942.0  Sea Disaster  ATLANTIC OCEAN              NaN
# 1723  01-Nov-2003  2003.0    Unprovoked       AUSTRALIA  New South Wales
# 245   16-Jul-2016  2016.0    Unprovoked             USA          Florida
# 2754  14-Jan-1988  1988.0      Provoked             USA        Louisiana
# 5532  08-Aug-1902  1902.0    Unprovoked             USA           Hawaii
# 1557  22-Aug-2005  2005.0       Invalid             USA   South Carolina
#
#                                                Location  \
# 582                    Goldsmith Beach, Yorke Peninsula
# 5913                             Hoogly River, Calcutta
# 5255  Between Bay Rock & Magnetic Island, Cleveland Bay
# 4578                         Country Club Beach, Durban
# 4707                                                NaN
# 1723                     Seal Rocks, north of Newcastle
# 245                    New Smyrna Beach, Volusia County
# 2754                                                NaN
# 5532                                      Kalihi, O'ahu
# 1557       6th Avenue North, Myrtle Beach, Horry County
#
#                                                Activity  \
# 582                          Spearfishing / Free diving
# 5913                                 Bathing / standing
# 5255                   Boat capsized, swimming to shore
# 4578                                     Treading water
# 4707  The SS Potlach was torpedoed & sunk by the U-1...
# 1723                                           Standing
# 245                                                 NaN
# 2754                                            Fishing
# 5532                                     Catching crabs
# 1557     Boogie boarding, kicked at object in the water
#
#                         Name Sex   Age  \
# 582             Sam Kellett     M   28
# 5913  B., "an Ooryah coolie"    M   40
# 5255          Alfred Burgess    M   20
# 4578   Aubrey "Bill" Nielsen    M   21
# 4707      John Martin Miller    M   32
# 1723                    male    M  NaN
# 245                   female    F   11
# 2754                    Chip    M  NaN
# 5532            Hawaiian boy    M  NaN
# 1557          Nicholas House    M   17
#
#                                                  Injury Fatal (Y/N)  \
# 582                                               FATAL           Y
# 5913      Right foot & leg bitten, surgically amputated           N
# 5255        Tossed in air by shark, sustained abrasions           N
# 4578                             Ankle & shin lacerated           N
# 4707                                   FATAL Arm bitten           Y
# 1723                    Minor lacerations to leg & foot           N
# 245                                Minor injury to toes           N
# 2754    Hand bitten by captured shark PROVOKED INCIDENT           N
# 5532                         FATAL, both arms severed             Y
# 1557  Laceration to knee, possibly by a  small black...         NaN
#
#            Time                         Species   \
# 582       12h00                              NaN
# 5913        NaN                              NaN
# 5255        NaN                              NaN
# 4578      12h00               1.5 m, 45-kg shark
# 4707        NaN                              NaN
# 1723       Dusk                              NaN
# 245       11h00                              NaN
# 2754        NaN                       Mako shark
# 5532        NaN                              NaN
# 1557  Afternoon  Shark involvement not confirmed
#
#                                  Investigator or Source  \
# 582                            The Advertiser, 2/9/2014
# 5913                                    J. Fayrer, M.D.
# 5255  H. Miller (1920); V.M. Coppleson Q.2.(1933); V...
# 4578           A. Nielsen, M. Levine, G. Charter, GSAF
# 4707                   Kingsport Times, 8/6/1942, et al
# 1723                            The Sun; 11/2/2003, p.9
# 245                         Orlando Sentinel, 7/21/2016
# 2754                                 C. Johansson, GSAF
# 5532  G. H. Balazs & A. H. Kam; V.M. Coppleson (1958...
# 1557                                Clay Creswell, GSAF
#
#                              pdf  \
# 582       2014.02.08-Kellett.pdf
# 5913       1870.06.01-Ooryah.pdf
# 5255      1920.03.08-Burgess.pdf
# 4578      1947.04.20-Neilson.pdf
# 4707       1942.07.12-Miller.pdf
# 1723    2003.11.01-SealRocks.pdf
# 245         2016.07.16.a-NSB.pdf
# 2754         1988.01.14-Chip.pdf
# 5532  1902.08.08-HawaiianBoy.pdf
# 1557        2005.08.22-House.pdf
#
#                                                    href Case Number.1  \
# 582   http://sharkattackfile.net/spreadsheets/pdf_di...    2014.02.08
# 5913  http://sharkattackfile.net/spreadsheets/pdf_di...    1870.06.01
# 5255  http://sharkattackfile.net/spreadsheets/pdf_di...    1920.03.08
# 4578  http://sharkattackfile.net/spreadsheets/pdf_di...    1947.04.20
# 4707  http://sharkattackfile.net/spreadsheets/pdf_di...    1942.07.12
# 1723  http://sharkattackfile.net/spreadsheets/pdf_di...    2003.11.01
# 245   http://sharkattackfile.net/spreadsheets/pdf_di...  2016.07.16.a
# 2754  http://sharkattackfile.net/spreadsheets/pdf_di...    1988.01.14
# 5532  http://sharkattackfile.net/spreadsheets/pdf_di...    1902.08.08
# 1557  http://sharkattackfile.net/spreadsheets/pdf_di...    2005.08.22
#
#       original order
# 582           5721.0
# 5913           390.0
# 5255          1048.0
# 4578          1725.0
# 4707          1596.0
# 1723          4580.0
# 245           6058.0
# 2754          3549.0
# 5532           771.0
# 1557          4746.0

# %%
# After running once again several "df.samples()" we choose to substitute the "NaN" values/types for 0 in all the 
# columns that we see we cannot guess a number.
df['Date'].fillna('-', inplace=True)
df['Year'].fillna('-', inplace=True)
df['Type'].fillna('-', inplace=True)
df['Country'].fillna('-', inplace=True)
df['Area'].fillna('-', inplace=True)
df['Location'].fillna('-', inplace=True)
df['Activity'].fillna('-', inplace=True)
df['Name'].fillna('-', inplace=True)
df['Injury'].fillna('-', inplace=True)
df['Time'].fillna('-', inplace=True)
df['Investigator or Source'].fillna('-', inplace=True)
df['pdf'].fillna('-', inplace=True)
df['href'].fillna('-', inplace=True)
df['Case Number.1'].fillna('-', inplace=True)
df['Sex '].fillna('-', inplace=True)
df['Fatal (Y/N)'].fillna('-', inplace=True)
df['Species '].fillna('-', inplace=True)

# %%
df.sample(5)
# Out:
#                  Date  Year        Type       Country  \
# 1250      07-Jun-2008  2008  Unprovoked           USA
# 2653      18-Nov-1989  1989  Unprovoked  SOUTH AFRICA
# 3815      11-Jun-1962  1962  Unprovoked           USA
# 1826      21-Sep-2002  2002  Unprovoked           USA
# 6184  Before Oct-2009     0  Unprovoked        PANAMA
#
#                          Area                      Location  \
# 1250                  Florida  Cocoa Beach, Brevard  County
# 2653    Western Cape Province                 Melkbosstrand
# 3815               California             San Francisco Bay
# 1826                   Oregon                  Cape Kiwanda
# 6184  Bocas del Toro Province                Red Frog Beach
#
#                         Activity                  Name Sex  Age  \
# 1250                Body surfing        John Vasbinder    M  40
# 2653  Free diving & spearfishing     Gerjo Van Niekerk    M  29
# 3815     Escaping from Alacatraz  John William Anglin     M  32
# 1826  Boogie boarding or Surfing          Garry Turner    M  24
# 6184                   Swimming/                  male    M  20
#
#                                                  Injury Fatal (Y/N)   Time  \
# 1250              Lacerations & abrasions to right hand           N      -
# 2653                                              FATAL           Y  12h05
# 3815  FATAL, but shark involvement uncomfirmed. Deat...           Y  Night
# 1826                                    Ankle lacerated           N
# 6184                                              FATAL           Y      -
#
#               Species              Investigator or Source  \
# 1250                 -                   TC Palm, 6/20/08
# 2653       White shark                    M. Levine, GSAF
# 3815                 -  San Francisco Chronicle, 5/3/1986
# 1826  2.4 m [8'] shark                 R. Collier, GSAF
# 6184                 -            C. Mendieta & A. Duarte
#
#                                pdf  \
# 1250      2008.06.07-Vasbinder.pdf
# 2653     1989.11.18-VanNiekerk.pdf
# 3815       1962.06.11.b-Anglin.pdf
# 1826  2002.09.21.b-GarryTurner.pdf
# 6184            ND-0151-Panama.pdf
#
#                                                    href Case Number.1  \
# 1250  http://sharkattackfile.net/spreadsheets/pdf_di...    2008.06.07
# 2653  http://sharkattackfile.net/spreadsheets/pdf_di...    1989.11.18
# 3815  http://sharkattackfile.net/spreadsheets/pdf_di...  1962.06.11.b
# 1826  http://sharkattackfile.net/spreadsheets/pdf_di...  2002.09.21.b
# 6184  http://sharkattackfile.net/spreadsheets/pdf_di...       ND-0151
#
#       original order
# 1250          5053.0
# 2653          3650.0
# 3815          2488.0
# 1826          4477.0
# 6184           119.0

# %%
# Now we are trying to use the "describe()" function in order to see if the "min()" value of the column 'Age' could 
# be equal to '0', so in that case it could be a good idea to turn all those 'NaN' values to '0' too, but since
# the column 'Age' is an object-type of column we cannot see any output when using "describe()" and also we are having
# trouble when trying to change it's type to int64 or float64, so we don't seem to be able to use the "describe()"
# function in any useful way in this case. The info with some algorithms to replace all those "NaN" values and other
# tips or hints can be found in this URL: 'https://towardsdatascience.com/whats-the-best-way-to-handle-nan-values-62d50f738fc'.
df['Age'].apply(np.int64)
df.describe()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-646-46056229d8c8> in <module>
#       5 # function in any useful way in this case. The info with some algorithms to replace all those "NaN" values and other
#       6 # tips or hints can be found in this URL: 'https://towardsdatascience.com/whats-the-best-way-to-handle-nan-values-62d50f738fc'.
# ----> 7 df['Age'].apply(np.int64)
#       8 df.describe()
#
# /usr/local/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4210             else:
#    4211                 values = self.astype(object)._values
# -> 4212                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4213
#    4214         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# ValueError: cannot convert float NaN to integer

# %%
# As we haven't found any other solution to this problem, We will proceed to change those 'NaN' values also for '-' too.
df['Age'].fillna('-', inplace=True)
df
# Out:
#              Date  Year        Type    Country             Area  \
# 0     25-Jun-2018  2018     Boating        USA       California
# 1     18-Jun-2018  2018  Unprovoked        USA          Georgia
# 2     09-Jun-2018  2018     Invalid        USA           Hawaii
# 3     08-Jun-2018  2018  Unprovoked  AUSTRALIA  New South Wales
# 4     04-Jun-2018  2018    Provoked     MEXICO           Colima
# ...           ...   ...         ...        ...              ...
# 6304            -     -           -          -                -
# 6305            -     -           -          -                -
# 6306            -     -           -          -                -
# 6307            -     -           -          -                -
# 6308            -     -           -          -                -
#
#                             Location     Activity             Name Sex  Age  \
# 0        Oceanside, San Diego County     Paddling      Julie Wolfe    F  57
# 1     St. Simon Island, Glynn County     Standing  Adyson McNeely     F  11
# 2                       Habush, Oahu      Surfing      John Denges    M  48
# 3                 Arrawarra Headland      Surfing             male    M   -
# 4                           La Ticla  Free diving   Gustavo Ramos     M   -
# ...                              ...          ...              ...  ...  ..
# 6304                               -            -                -    -   -
# 6305                               -            -                -    -   -
# 6306                               -            -                -    -   -
# 6307                               -            -                -    -   -
# 6308                               -            -                -    -   -
#
#                                                  Injury Fatal (Y/N)  \
# 0     No injury to occupant, outrigger canoe and pad...           N
# 1                            Minor injury to left thigh           N
# 2          Injury to left lower leg from surfboard skeg           N
# 3                             Minor injury to lower leg           N
# 4     Lacerations to leg & hand shark PROVOKED INCIDENT           N
# ...                                                 ...         ...
# 6304                                                  -           -
# 6305                                                  -           -
# 6306                                                  -           -
# 6307                                                  -           -
# 6308                                                  -           -
#
#                Time         Species           Investigator or Source  \
# 0             18h00      White shark                R. Collier, GSAF
# 1     14h00  -15h00                -  K.McMurray, TrackingSharks.com
# 2             07h45                -  K.McMurray, TrackingSharks.com
# 3                 -        2 m shark                  B. Myatt, GSAF
# 4                 -  Tiger shark, 3m                       A .Kipper
# ...             ...              ...                             ...
# 6304              -                -                               -
# 6305              -                -                               -
# 6306              -                -                               -
# 6307              -                -                               -
# 6308              -                -                               -
#
#                            pdf  \
# 0         2018.06.25-Wolfe.pdf
# 1       2018.06.18-McNeely.pdf
# 2        2018.06.09-Denges.pdf
# 3     2018.06.08-Arrawarra.pdf
# 4         2018.06.04-Ramos.pdf
# ...                        ...
# 6304                         -
# 6305                         -
# 6306                         -
# 6307                         -
# 6308                         -
#
#                                                    href Case Number.1  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                 ...           ...
# 6304                                                  -             -
# 6305                                                  -             -
# 6306                                                  -             -
# 6307                                                  -             -
# 6308                                                  -             -
#
#       original order
# 0             6303.0
# 1             6302.0
# 2             6301.0
# 3             6300.0
# 4             6299.0
# ...              ...
# 6304          6306.0
# 6305          6307.0
# 6306          6308.0
# 6307          6309.0
# 6308          6310.0
#
# [6309 rows x 19 columns]

# %%
# Now, we proceed to save the cleaned dataframe and then analyze it.
df.to_csv('../Pandas-project/attacks_clean.csv')
